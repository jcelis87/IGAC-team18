# %%
import googlemaps
import json
import pandas as pd

# %%
API_KEY = "AIzaSyBkOIznkEPEOgYt6SnyMgz4G9vIawCue1M"

# %%
import requests
from urllib.parse import urlencode

def geocode(address):
    # Send request by API
    response = requests.get(
        'https://maps.googleapis.com/maps/api/geocode/json?' + urlencode(
            {'address': address, 'key': API_KEY, 'sensor': 'false'}))
    # Read response as json
    resp_address = response.json()
    # status=OK: the place was successfully detected and at least one result was returned
    if resp_address['status'] == 'OK':
        lat = resp_address['results'][0]['geometry']['location']['lat']
        lng = resp_address['results'][0]['geometry']['location']['lng']
        formatted_addr = resp_address['results'][0]['formatted_address']
        return [lat, lng, formatted_addr]
    else:
        return [0, 0, address]

# %%
def place_search(lugar, lat,long):
    
    #place search website requiered for the request
    place_search_url = "https://maps.googleapis.com/maps/api/place/findplacefromtext/json?"
    
    place_search_params = {
        "key": API_KEY,
        "region": ".co",
        "language": "es",
        "input": str(lugar),
        "inputtype": "textquery",
        "locationbias":"circle:500@"+str(lat)+","+str(long),
        "type":"hospital",
        "fields": "name,place_id,formatted_address,types"} #opening_hours is missing
    find_response = requests.request("GET", place_search_url, params=place_search_params)
    find_result = json.loads(find_response.text)
    return find_result

# %%
def place_details(google_id):
    
    #Place details website requiered for the request
    place_details_url = "https://maps.googleapis.com/maps/api/place/details/json"

    details_params = {
        "key": API_KEY,
        "language": "es",
        "region": ".co",
        "place_id": google_id,
        "fields": "name,types,formatted_address,place_id"} #opening_hours is missing

    details_response = requests.request("GET", place_details_url, params=details_params)

    data=json.loads(details_response.text)
    return data

# %%
place_search("Chaparral", "Tolima")
# Out:
# {'candidates': [{'formatted_address': 'Chaparral, Tolima, Colombia',
#    'name': 'Chaparral',
#    'place_id': 'ChIJf-4AJvRkOY4RAfuwSda_Vao',
#    'types': ['administrative_area_level_2', 'political']}],
#  'status': 'OK'}

# %%
place_search("Iglesia Chaparral", "Tolima")
# Out:
# {'candidates': [{'formatted_address': 'Chaparral, Tolima, Colombia',
#    'name': 'Iglesia San Juan Bautista',
#    'place_id': 'ChIJudPx-vRkOY4RiFlGyBklFgU',
#    'types': ['church',
#     'place_of_worship',
#     'point_of_interest',
#     'establishment']}],
#  'status': 'OK'}

# %%
place_search("rio Chaparral", "Tolima")
# Out:
# {'candidates': [{'formatted_address': 'Río Amoyá, Chaparral, Tolima, Colombia',
#    'name': 'Río Amoyá',
#    'place_id': 'ChIJm39mQ6JhOY4RsxP8PU4ybCA',
#    'types': ['natural_feature', 'establishment']}],
#  'status': 'OK'}

# %%
place_details('ChIJf-4AJvRkOY4RAfuwSda_Vao')
# Out:
# {'html_attributions': [],
#  'result': {'formatted_address': 'Chaparral, Tolima, Colombia',
#   'name': 'Chaparral',
#   'place_id': 'ChIJf-4AJvRkOY4RAfuwSda_Vao',
#   'types': ['administrative_area_level_2', 'political']},
#  'status': 'OK'}

# %%
geocode("Chaparral, Tolima")
# Out:
# [3.7440073, -75.5742467, 'Chaparral, Tolima, Colombia']

# %%
geocode("Río Amoyá Chaparral, Tolima")
# Out:
# [3.656096, -75.4152283, 'Río Amoyá, Chaparral, Tolima, Colombia']

# %%
place_search("Chaparral Tolima", 3.656096, -75.41)
# Out:
# {'candidates': [{'formatted_address': 'Chaparral, Tolima, Colombia',
#    'name': 'Chaparral',
#    'place_id': 'ChIJf-4AJvRkOY4RAfuwSda_Vao',
#    'types': ['administrative_area_level_2', 'political']}],
#  'status': 'OK'}

# %%
def nearby(lat, long):


    autocomplete_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    details_params = {

        "key": API_KEY,
        "location":str(lat)+","+str(long),
        "radius": "2200",
        "type":"church"

    }

    details_response = requests.request("GET", autocomplete_url, params=details_params)
    data=json.loads(details_response.text)
    return data

# %%
results=nearby(3.724852725400337, -75.48424304856047)

# %%
results['results']
# Out:
# [{'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 3.724062099999999, 'lng': -75.4834448},
#    'viewport': {'northeast': {'lat': 3.725455080291502,
#      'lng': -75.4821017197085},
#     'southwest': {'lat': 3.722757119708497, 'lng': -75.4847996802915}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/worship_general-71.png',
#   'icon_background_color': '#7B9EB0',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/worship_christian_pinlet',
#   'name': 'Iglesia Apostólica Jesucristo Justicia Nuestra',
#   'photos': [{'height': 1456,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108208587982714800641">Yordy Martín Hernández Rojas</a>'],
#     'photo_reference': 'Aap_uED9I80ubE0k_0pl_PDkaA1YGlp3X-T1COiqSzDlQAOdLSpV7fdj406fxFNCnara6WNAESpGNUbWxyCLD1dl6YTVM3I9WdOYD2l-CnU6Ea4ZASnUuFT-kCIuNwj3SR9yqNVVwt2llttNdMwgY2A7QQ0lKJdYzn9o2ydatQWdMs1q-SP_',
#     'width': 2592}],
#   'place_id': 'ChIJBeBhGPVkOY4RRvQ9HLJPXC0',
#   'plus_code': {'compound_code': 'PGF8+JJ Chaparral, Tolima, Colombia',
#    'global_code': '67M6PGF8+JJ'},
#   'rating': 2.3,
#   'reference': 'ChIJBeBhGPVkOY4RRvQ9HLJPXC0',
#   'scope': 'GOOGLE',
#   'types': ['church',
#    'place_of_worship',
#    'point_of_interest',
#    'establishment'],
#   'user_ratings_total': 3,
#   'vicinity': ''},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 3.724751999999999,
#     'lng': -75.48459489999999},
#    'viewport': {'northeast': {'lat': 3.726056330291502,
#      'lng': -75.48328001970847},
#     'southwest': {'lat': 3.723358369708497, 'lng': -75.4859779802915}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/worship_general-71.png',
#   'icon_background_color': '#7B9EB0',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/worship_christian_pinlet',
#   'name': 'Iglesia San Juan Bautista',
#   'photos': [{'height': 3264,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102606201821128340537">Andrés García Zuluaga</a>'],
#     'photo_reference': 'Aap_uEBQuG3OSBof6gu2Mt9wjmJ6NBI3aFGr9PD00hYW7MMZSwT2VqXLyGJuxyaODNQNiZQTxZVGvwzcKaRmb9VvYtJaC-gSE05NGufDymoNaQSd770QRYgBLK4w7xHGfrysmaptAzbry2ENFutfwemvrXegcTLGMVojATvqvoTDnjAiOic6',
#     'width': 1472}],
#   'place_id': 'ChIJudPx-vRkOY4RiFlGyBklFgU',
#   'plus_code': {'compound_code': 'PGF8+W5 Chaparral, Tolima, Colombia',
#    'global_code': '67M6PGF8+W5'},
#   'rating': 4.9,
#   'reference': 'ChIJudPx-vRkOY4RiFlGyBklFgU',
#   'scope': 'GOOGLE',
#   'types': ['church',
#    'place_of_worship',
#    'point_of_interest',
#    'establishment'],
#   'user_ratings_total': 31,
#   'vicinity': ''},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 3.7248523, 'lng': -75.48467629999999},
#    'viewport': {'northeast': {'lat': 3.726144430291502,
#      'lng': -75.48337066970849},
#     'southwest': {'lat': 3.723446469708498, 'lng': -75.4860686302915}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/worship_general-71.png',
#   'icon_background_color': '#7B9EB0',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/worship_christian_pinlet',
#   'name': 'Parroquia de Chaparral',
#   'photos': [{'height': 3120,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117600005992517386111">Juan David Ochoa</a>'],
#     'photo_reference': 'Aap_uECPwDNax7tdBVZlpmS3q4kxW6CZrbQbGx0bkVOaSk2udyNMv2ja85sXE7fgrshXTYJiTZSE9j6Rzv0v9KEHriz9LB4zqp5hRglmwcA-4zf-k5cuDY8G1PlTWs11Q8nUp1eZnyy_QfTnEsQyUuYtMGYQnGxJpyDYFkwBkryb9hSyTyno',
#     'width': 4160}],
#   'place_id': 'ChIJew1y-vRkOY4RBI-t5L5ElDI',
#   'plus_code': {'compound_code': 'PGF8+W4 Chaparral, Tolima, Colombia',
#    'global_code': '67M6PGF8+W4'},
#   'rating': 4.7,
#   'reference': 'ChIJew1y-vRkOY4RBI-t5L5ElDI',
#   'scope': 'GOOGLE',
#   'types': ['church',
#    'place_of_worship',
#    'point_of_interest',
#    'establishment'],
#   'user_ratings_total': 13,
#   'vicinity': ''},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 3.723484, 'lng': -75.48297099999999},
#    'viewport': {'northeast': {'lat': 3.724785330291501,
#      'lng': -75.4816593197085},
#     'southwest': {'lat': 3.722087369708497, 'lng': -75.4843572802915}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/worship_general-71.png',
#   'icon_background_color': '#7B9EB0',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/worship_christian_pinlet',
#   'name': 'Christian Alliance Church',
#   'place_id': 'ChIJdZo5OvVkOY4RZdL3J45iCl0',
#   'plus_code': {'compound_code': 'PGF8+9R Chaparral, Tolima, Colombia',
#    'global_code': '67M6PGF8+9R'},
#   'rating': 4.7,
#   'reference': 'ChIJdZo5OvVkOY4RZdL3J45iCl0',
#   'scope': 'GOOGLE',
#   'types': ['church',
#    'place_of_worship',
#    'point_of_interest',
#    'establishment'],
#   'user_ratings_total': 3,
#   'vicinity': ''},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 3.724871799999999, 'lng': -75.4817739},
#    'viewport': {'northeast': {'lat': 3.726124030291502,
#      'lng': -75.48049826970849},
#     'southwest': {'lat': 3.723426069708497, 'lng': -75.4831962302915}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/worship_general-71.png',
#   'icon_background_color': '#7B9EB0',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/worship_christian_pinlet',
#   'name': 'CENTRO MISIONERO BETHESDA CHAPARRAL',
#   'photos': [{'height': 2322,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/118168043068114430346">CAROLINA LIZCANO DÍAZ</a>'],
#     'photo_reference': 'Aap_uEDlimzo4lYCyxQup_Y6hmeH_ImWzj01VedBiWZURG7ezeGHGF8_xhUwmv4gCFqmZQ8tfXu8s44rExYBXgligacGzRNBfdApmF73LKjTwNZ97sZ-knsA4r7-UFVob2Lzs-t1PfnwDPPetIDv3NCzYhGCb5A4pl-2MAdRRQcopWybPETz',
#     'width': 4128}],
#   'place_id': 'ChIJw31IA_5lOY4ROJYHEfqLAvI',
#   'plus_code': {'compound_code': 'PGF9+W7 Chaparral, Tolima, Colombia',
#    'global_code': '67M6PGF9+W7'},
#   'rating': 5,
#   'reference': 'ChIJw31IA_5lOY4ROJYHEfqLAvI',
#   'scope': 'GOOGLE',
#   'types': ['church',
#    'place_of_worship',
#    'point_of_interest',
#    'establishment'],
#   'user_ratings_total': 2,
#   'vicinity': 'calle 11 N. 5-42 barrio versalles'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 3.7240077, 'lng': -75.4866758},
#    'viewport': {'northeast': {'lat': 3.725401630291502,
#      'lng': -75.4852932197085},
#     'southwest': {'lat': 3.722703669708498, 'lng': -75.4879911802915}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/worship_general-71.png',
#   'icon_background_color': '#7B9EB0',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/worship_christian_pinlet',
#   'name': 'Iglesia Adventista del Séptimo Día Chaparral',
#   'photos': [{'height': 1920,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106530711799537462349">Gerson Castañeda Suns</a>'],
#     'photo_reference': 'Aap_uEANSeOl0QxSFbJ4X42GESYDUeT0PvE7ips5uqxcBb3yRoAkKIKJxbsCalcdE1wD3qZAHXNa7Ans2OOvToWfyr7zkNf8FBxGrXLo0sdZjpHUMB0el8UcQBbg-ew3g6Lbo0lpUqNiysr9oxIU59KM7YDs9Vb0smlTR2g5P_xvwku2ZwrX',
#     'width': 2560}],
#   'place_id': 'ChIJTZ-VnvRkOY4Rog4J165iBb4',
#   'plus_code': {'compound_code': 'PGF7+J8 Chaparral, Tolima, Colombia',
#    'global_code': '67M6PGF7+J8'},
#   'rating': 4.3,
#   'reference': 'ChIJTZ-VnvRkOY4Rog4J165iBb4',
#   'scope': 'GOOGLE',
#   'types': ['church',
#    'place_of_worship',
#    'point_of_interest',
#    'establishment'],
#   'user_ratings_total': 8,
#   'vicinity': ''},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 3.7251759, 'lng': -75.481672},
#    'viewport': {'northeast': {'lat': 3.726594580291502,
#      'lng': -75.48040461970851},
#     'southwest': {'lat': 3.723896619708498, 'lng': -75.48310258029151}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/worship_general-71.png',
#   'icon_background_color': '#7B9EB0',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/worship_christian_pinlet',
#   'name': 'Iglesia Adventista Filadelfia',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3456,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115051384238733004203">julian andres salcedo ducuara</a>'],
#     'photo_reference': 'Aap_uEAjZHvRdR9jnu0oMTY9zdvRTkz_NIpaI2aU5GFxyv5QrSEXwx20Prw4xkC2GkHA-XlESvbABCv4e5R5bpzmo1f2P_RfmfqfAUwc8ExVQ3DWwlYHk449vLiYWw9XqP6P_hjOUsgp2NIS6geje_Q2ERk5O2Dsacl99jmGbhoci57rZC6w',
#     'width': 4608}],
#   'place_id': 'ChIJoZtwePVkOY4RhNsjOKXWw3s',
#   'plus_code': {'compound_code': 'PGG9+38 Chaparral, Tolima, Colombia',
#    'global_code': '67M6PGG9+38'},
#   'rating': 4.7,
#   'reference': 'ChIJoZtwePVkOY4RhNsjOKXWw3s',
#   'scope': 'GOOGLE',
#   'types': ['church',
#    'place_of_worship',
#    'point_of_interest',
#    'establishment'],
#   'user_ratings_total': 6,
#   'vicinity': ''},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 3.7215662, 'lng': -75.4836538},
#    'viewport': {'northeast': {'lat': 3.722987380291502,
#      'lng': -75.48224811970849},
#     'southwest': {'lat': 3.720289419708497, 'lng': -75.48494608029151}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/worship_general-71.png',
#   'icon_background_color': '#7B9EB0',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/worship_christian_pinlet',
#   'name': 'Iglesia De Dios Ministerial De Jesucristo Internacional',
#   'photos': [{'height': 2448,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109595748565506352062">Edward Cardenas</a>'],
#     'photo_reference': 'Aap_uEA-RHHD15ChJR0I_RSaQ3OQTVDuYhVluFCYvZZrzhZmD_ZjoIp8T-_T8Zgs1fOCMBYkY8rchBl_-G8WD7yMtip4ZNtS5kIgdTMv0Uljy4mT_DfDBrmzOa0zIdK_dd7Al3cGK0eY-xTD1KJaWukv67XzinChoYwlXlKeFSEXya7-gYHH',
#     'width': 3264}],
#   'place_id': 'ChIJySC03opkOY4R7ALW4wcSvW4',
#   'plus_code': {'compound_code': 'PGC8+JG Chaparral, Tolima, Colombia',
#    'global_code': '67M6PGC8+JG'},
#   'rating': 3.8,
#   'reference': 'ChIJySC03opkOY4R7ALW4wcSvW4',
#   'scope': 'GOOGLE',
#   'types': ['church',
#    'place_of_worship',
#    'point_of_interest',
#    'establishment'],
#   'user_ratings_total': 20,
#   'vicinity': 'Calle 7'}]

# %%
results['results'][0]['types'][0]
# Out:
# 'church'

# %%
name=[]
lat=[]
long=[]
tags=[]

for i in results['results']:
    name.append(i['name'])
    lat.append(i['geometry']['location']['lat'])
    long.append(i['geometry']['location']['lng'])
    tags.append(i['types'][0])

# %%
name
# Out:
# ['Iglesia Apostólica Jesucristo Justicia Nuestra',
#  'Iglesia San Juan Bautista',
#  'Parroquia de Chaparral',
#  'Christian Alliance Church',
#  'CENTRO MISIONERO BETHESDA CHAPARRAL',
#  'Iglesia Adventista del Séptimo Día Chaparral',
#  'Iglesia Adventista Filadelfia',
#  'Iglesia De Dios Ministerial De Jesucristo Internacional']

# %%
tags
# Out:
# ['church',
#  'church',
#  'church',
#  'church',
#  'church',
#  'church',
#  'church',
#  'church']

# %%
def nearby_tag(lat, long,tag):


    autocomplete_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    details_params = {

        "key": API_KEY,
        "location":str(lat)+","+str(long),
        "radius": "2200",
        "keyword":str(tag)

    }

    details_response = requests.request("GET", autocomplete_url, params=details_params)
    data=json.loads(details_response.text)
    return data

# %%
def sacar_info(dictionary_json):
    name=[]
    lat=[]
    long=[]
    tags=[]

    for i in dictionary_json['results']:
        name.append(i['name'])
        lat.append(i['geometry']['location']['lat'])
        long.append(i['geometry']['location']['lng'])
        tags.append(i['types'][0])
    
    df=pd.DataFrame({'geographic_name': name, 'latitude': lat,'longitude': long,'site_type':tags})

    return df

# %%
lista=["accounting","airport","church"]


df_empty2 = pd.DataFrame(columns=['geographic_name','latitude','longitude','site_type'])

for i in lista:
    x=nearby_tag(3.724852725400337, -75.48424304856047,i)
    df=sacar_info(x)
    df_empty2.append(df)

# %%
df_empty
# Out:
#                                      geographic_name  latitude  longitude  \
# 0     Iglesia Apostólica Jesucristo Justicia Nuestra  3.724062 -75.483445
# 1                          Iglesia San Juan Bautista  3.724752 -75.484595
# 2                             Parroquia de Chaparral  3.724852 -75.484676
# 3                          Christian Alliance Church  3.723484 -75.482971
# 4                CENTRO MISIONERO BETHESDA CHAPARRAL  3.724872 -75.481774
# 5       Iglesia Adventista del Séptimo Día Chaparral  3.724008 -75.486676
# 6                      Iglesia Adventista Filadelfia  3.725176 -75.481672
# 7  Iglesia De Dios Ministerial De Jesucristo Inte...  3.721566 -75.483654
# 0     Iglesia Apostólica Jesucristo Justicia Nuestra  3.724062 -75.483445
# 1                          Iglesia San Juan Bautista  3.724752 -75.484595
# 2                             Parroquia de Chaparral  3.724852 -75.484676
# 3                          Christian Alliance Church  3.723484 -75.482971
# 4                CENTRO MISIONERO BETHESDA CHAPARRAL  3.724872 -75.481774
# 5       Iglesia Adventista del Séptimo Día Chaparral  3.724008 -75.486676
# 6                      Iglesia Adventista Filadelfia  3.725176 -75.481672
# 7  Iglesia De Dios Ministerial De Jesucristo Inte...  3.721566 -75.483654
# 0     Iglesia Apostólica Jesucristo Justicia Nuestra  3.724062 -75.483445
# 1                          Iglesia San Juan Bautista  3.724752 -75.484595
# 2                             Parroquia de Chaparral  3.724852 -75.484676
# 3                          Christian Alliance Church  3.723484 -75.482971
# 4                CENTRO MISIONERO BETHESDA CHAPARRAL  3.724872 -75.481774
# 5       Iglesia Adventista del Séptimo Día Chaparral  3.724008 -75.486676
# 6                      Iglesia Adventista Filadelfia  3.725176 -75.481672
# 7  Iglesia De Dios Ministerial De Jesucristo Inte...  3.721566 -75.483654
#
#   site_type
# 0    church
# 1    church
# 2    church
# 3    church
# 4    church
# 5    church
# 6    church
# 7    church
# 0    church
# 1    church
# 2    church
# 3    church
# 4    church
# 5    church
# 6    church
# 7    church
# 0    church
# 1    church
# 2    church
# 3    church
# 4    church
# 5    church
# 6    church
# 7    church

# %%
lista_final=["accounting","airport","amusement_park","aquarium"
,"art_gallery"
,"atm"
,"bakery"
,"bank"
,"bar"
,"beauty_salon"
,"bicycle_store"
,"book_store"
,"bowling_alley"
,"bus_station"
,"cafe"
,"campground"
,"car_dealer"
,"car_rental"
,"car_repair"
,"car_wash"
,"casino"
,"cemetery"
,"church"
,"city_hall"
,"clothing_store"
,"convenience_store"
,"courthouse"
,"dentist"
,"department_store"
,"doctor"
,"drugstore"
,"electrician"
,"electronics_store"
,"embassy"
,"fire_station"
,"florist"
,"funeral_home"
,"furniture_store"
,"gas_station"
,"gym"
,"hair_care"
,"hardware_store"
,"hindu_temple"
,"home_goods_store"
,"hospital"
,"insurance_agency"
,"jewelry_store"
,"laundry"
,"lawyer"
,"library"
,"light_rail_station"
,"liquor_store"
,"local_government_office"
,"locksmith"
,"lodging"
,"meal_delivery"
,"meal_takeaway"
,"mosque"
,"movie_rental"
,"movie_theater"
,"moving_company"
,"museum"
,"night_club"
,"painter"
,"park"
,"parking"
,"pet_store"
,"pharmacy"
,"physiotherapist"
,"plumber"
,"police"
,"post_office"
,"primary_school"
,"real_estate_agency"
,"restaurant"
,"roofing_contractor"
,"rv_park"
,"school"
,"secondary_school"
,"shoe_store"
,"shopping_mall"
,"spa"
,"stadium"
,"storage"
,"store"
,"subway_station"
,"supermarket"
,"synagogue"
,"taxi_stand"
,"tourist_attraction"
,"train_station"
,"transit_station"
,"travel_agency"
,"university"
,"veterinary_care"
,"zoo"
       
      ]

# %%
df_google = pd.DataFrame(columns=['geographic_name','latitude','longitude','site_type'])

for i in lista_final:
    
    x=nearby_tag(3.724852725400337, -75.48424304856047,i)
    df=sacar_info(x)
    df_google=df_google.append(df)

# %%
df_google.shape
# Out:
# (249, 4)

# %%
df_google["site_type"].unique()
# Out:
# array(['airport', 'atm', 'bank', 'bakery', 'supermarket', 'cafe', 'food',
#        'book_store', 'point_of_interest', 'florist', 'home_goods_store',
#        'bar', 'restaurant', 'night_club', 'bicycle_store', 'police',
#        'cemetery', 'church', 'local_government_office', 'dentist',
#        'doctor', 'health', 'drugstore', 'pharmacy', 'funeral_home', 'gym',
#        'hospital', 'library', 'lodging', 'museum', 'park', 'parking',
#        'fire_station', 'school', 'secondary_school', 'spa', 'gas_station',
#        'storage', 'grocery_or_supermarket', 'liquor_store',
#        'hardware_store', 'clothing_store', 'furniture_store',
#        'electronics_store', 'university'], dtype=object)

# %%
df_google=df_google.drop_duplicates(subset=['geographic_name','latitude','longitude'])
df_google=df_google.reset_index()

# %%
df_google
# Out:
#      level_0  index                                    geographic_name  \
# 0          0      0                                    Gen Navas Pardo
# 1          1      0                  Cajero Automático Banco de Bogotá
# 2          2      1                  Bancolombia Corresponsal Bancario
# 3          3      2                                 Cajero Bancolombia
# 4          4      3                  Corresponsal Bancario Bancolombia
# ..       ...    ...                                                ...
# 203      244     19                             Servifruver El Nuestro
# 204      245      0                                         COINTRASUR
# 205      246      0                                  Tolima University
# 206      247      1  CUN - Corporación Unificada Nacional de Educac...
# 207      248      2                     EDUPOL - POLITECNICO TOLIMENSE
#
#      latitude  longitude          site_type
# 0    3.723689 -75.467512            airport
# 1    3.724039 -75.485257                atm
# 2    3.723827 -75.483979                atm
# 3    3.725747 -75.484756                atm
# 4    3.723269 -75.484620               bank
# ..        ...        ...                ...
# 203  3.722618 -75.484537        supermarket
# 204  3.723603 -75.485442  point_of_interest
# 205  3.717292 -75.475570         university
# 206  3.719979 -75.495524         university
# 207  3.722864 -75.487175         university
#
# [208 rows x 6 columns]

# %%
from shapely.geometry import Point
